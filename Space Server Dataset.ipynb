# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Dataset Description

# %% [markdown]
# The dataset contains 10,000 observations of outerspace taken by the SDSS (Sloan Digital Sky Survey). Every observation is described by 17 features and 1 categorical feature which identifies whether it's a star, galaxy or quasar.

# %% [markdown]
# # Features Description

# %% [raw]
# objid = Observation Number
# ra = J2000 Right Ascension (r-band) #celestial sphere coordinate
# dec = J2000 Declination (r-band) #celestial sphere coordinate
# u = better of DeV/Exp magnitude fit #response of the u band of the telescope
# g = better of DeV/Exp magnitude fit #response of the g band of the telescope
# r = better of DeV/Exp magnitude fit #response of the r band of the telescope
# i = better of DeV/Exp magnitude fit #response of the i band of the telescope
# z = better of DeV/Exp magnitude fit #response of the z band of the telescope
# run = Run Number #
# rereun = Rerun Number
# camcol = Camera column
# field = Field number
# specobjid = Object Identifier
# class = object class (galaxy, star or quasar object)
# redshift = Final Redshift
# plate = plate number
# mjd = MJD (Modified Julian Date) of observation
# fiberid = fiber ID

# %%
df = pd.read_csv("space_server_dataset.csv")
df.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
#
#           z  run  rerun  camcol  field     specobjid   class  redshift  plate  \
# 0  15.22531  752    301       4    267  3.722360e+18    STAR -0.000009   3306
# 1  16.39150  752    301       4    267  3.638140e+17    STAR -0.000055    323
# 2  16.80125  752    301       4    268  3.232740e+17  GALAXY  0.123111    287
# 3  15.90438  752    301       4    269  3.722370e+18    STAR -0.000111   3306
# 4  16.61326  752    301       4    269  3.722370e+18    STAR  0.000590   3306
#
#      mjd  fiberid
# ...

# %% [markdown]
# Let's load the full feature names

# %%
feature_names = {"objid":"Object_Identifier","ra":"J2000 Right Ascension","dec":"J2000 Declination","u":"u","g":"g","r":"r","i":"i","z":"z","run":"Run_Number","rerun":"Rerun_Number","camcol":"Camera_column","field":"Field_number","specobjid":"Space_Object_Identifier","class":"object_class","redshift":"Final_Redshift","plate":"plate_number","mjd":"MJD_of_observation","fiberid":"fiber_ID"}
feature_names
# Out:
# {'objid': 'Object_Identifier',
#  'ra': 'J2000 Right Ascension',
#  'dec': 'J2000 Declination',
#  'u': 'u',
#  'g': 'g',
#  'r': 'r',
#  'i': 'i',
#  'z': 'z',
#  'run': 'Run_Number',
#  'rerun': 'Rerun_Number',
#  'camcol': 'Camera_column',
#  'field': 'Field_number',
#  'specobjid': 'Space_Object_Identifier',
#  'class': 'object_class',
#  'redshift': 'Final_Redshift',
#  'plate': 'plate_number',
#  'mjd': 'MJD_of_observation',
#  'fiberid': 'fiber_ID'}

# %%
df.rename(index=str,columns=feature_names,inplace=True)
df.head()
# Out:
#    Object_Identifier  J2000 Right Ascension  J2000 Declination         u  \
# 0       1.237650e+18             183.531326           0.089693  19.47406
# 1       1.237650e+18             183.598371           0.135285  18.66280
# 2       1.237650e+18             183.680207           0.126185  19.38298
# 3       1.237650e+18             183.870529           0.049911  17.76536
# 4       1.237650e+18             183.883288           0.102557  17.55025
#
#           g         r         i         z  Run_Number  Rerun_Number  \
# 0  17.04240  15.94699  15.50342  15.22531         752           301
# 1  17.21449  16.67637  16.48922  16.39150         752           301
# 2  18.19169  17.47428  17.08732  16.80125         752           301
# 3  16.60272  16.16116  15.98233  15.90438         752           301
# 4  16.26342  16.43869  16.55492  16.61326         752           301
#
#    Camera_column  Field_number  Space_Object_Identifier object_class  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Object_Identifier        10000 non-null  float64
#  1   J2000 Right Ascension    10000 non-null  float64
#  2   J2000 Declination        10000 non-null  float64
#  3   u                        10000 non-null  float64
#  4   g                        10000 non-null  float64
#  5   r                        10000 non-null  float64
#  6   i                        10000 non-null  float64
#  7   z                        10000 non-null  float64
#  8   Run_Number               10000 non-null  int64
#  9   Rerun_Number             10000 non-null  int64
#  10  Camera_column            10000 non-null  int64
#  11  Field_number             10000 non-null  int64
#  12  Space_Object_Identifier  10000 non-null  float64
#  13  object_class             10000 non-null  object
# ...

# %%
df.shape
# Out:
# (10000, 18)

# %% [markdown]
# Let's look into the distribution of the features

# %%
df["Object_Identifier"].value_counts()
# Out:
# 1.237650e+18    10000
# Name: Object_Identifier, dtype: int64

# %% [markdown]
# Clearly the Object_Identifier column is observaton number and doesn't contain any useful info, so let's delete it

# %%
df.drop("Object_Identifier",axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   J2000 Right Ascension    10000 non-null  float64
#  1   J2000 Declination        10000 non-null  float64
#  2   u                        10000 non-null  float64
#  3   g                        10000 non-null  float64
#  4   r                        10000 non-null  float64
#  5   i                        10000 non-null  float64
#  6   z                        10000 non-null  float64
#  7   Run_Number               10000 non-null  int64
#  8   Rerun_Number             10000 non-null  int64
#  9   Camera_column            10000 non-null  int64
#  10  Field_number             10000 non-null  int64
#  11  Space_Object_Identifier  10000 non-null  float64
#  12  object_class             10000 non-null  object
#  13  Final_Redshift           10000 non-null  float64
# ...

# %%
plt.figure(figsize=(14,8))
sns.distplot(df["J2000 Right Ascension"])
#plt.xticks(rotation = 90)
plt.xlabel('J2000 Right Ascension')
plt.ylabel('Frequency Density')
plt.title('J2000 Right Ascension - Distplot')
# Out:
# Text(0.5, 1.0, 'J2000 Right Ascension - Distplot')

# %%
plt.figure(figsize=(14,8))
sns.distplot(df["J2000 Declination"])
#plt.xticks(rotation = 90)
plt.xlabel('J2000 Declination')
plt.ylabel('Frequency Density')
plt.title('J2000 Declination - Distplot')
# Out:
# Text(0.5, 1.0, 'J2000 Declination - Distplot')

# %%
plt.figure(figsize=(14,8))
sns.distplot(df["u"])
#plt.xticks(rotation = 90)
plt.xlabel('u')
plt.ylabel('Frequency Density')
plt.title('Response of the u band of the telescope - Distplot')
# Out:
# Text(0.5, 1.0, 'Response of the u band of the telescope - Distplot')

# %% [markdown]
# The above plot is skewed to the left

# %%
plt.figure(figsize=(14,8))
sns.distplot(df["g"])
#plt.xticks(rotation = 90)
plt.xlabel('g')
plt.ylabel('Frequency Density')
plt.title('Response of the g band of the telescope - Distplot')
# Out:
# Text(0.5, 1.0, 'Response of the g band of the telescope - Distplot')

# %% [markdown]
# The above plot is skewed to the left

# %%
plt.figure(figsize=(14,8))
sns.distplot(df["r"])
#plt.xticks(rotation = 90)
plt.xlabel('r')
plt.ylabel('Frequency Density')
plt.title('Response of the r band of the telescope - Distplot')
# Out:
# Text(0.5, 1.0, 'Response of the r band of the telescope - Distplot')

# %% [markdown]
# The above plot approximates a normal distirbution

# %%
plt.figure(figsize=(14,8))
sns.distplot(df["i"])
#plt.xticks(rotation = 90)
plt.xlabel('i')
plt.ylabel('Frequency Density')
plt.title('Response of the i band of the telescope - Distplot')
# Out:
# Text(0.5, 1.0, 'Response of the i band of the telescope - Distplot')

# %%
plt.figure(figsize=(14,8))
sns.distplot(df["z"])
#plt.xticks(rotation = 90)
plt.xlabel('z')
plt.ylabel('Frequency Density')
plt.title('Response of the z band of the telescope - Distplot')
# Out:
# Text(0.5, 1.0, 'Response of the z band of the telescope - Distplot')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   J2000 Right Ascension    10000 non-null  float64
#  1   J2000 Declination        10000 non-null  float64
#  2   u                        10000 non-null  float64
#  3   g                        10000 non-null  float64
#  4   r                        10000 non-null  float64
#  5   i                        10000 non-null  float64
#  6   z                        10000 non-null  float64
#  7   Run_Number               10000 non-null  int64
#  8   Rerun_Number             10000 non-null  int64
#  9   Camera_column            10000 non-null  int64
#  10  Field_number             10000 non-null  int64
#  11  Space_Object_Identifier  10000 non-null  float64
#  12  object_class             10000 non-null  object
#  13  Final_Redshift           10000 non-null  float64
# ...

# %%
plt.figure(figsize=(14,8))
sns.distplot(df["Run_Number"])
#plt.xticks(rotation = 90)
plt.xlabel('Run_Number')
plt.ylabel('Frequency Desnity')
plt.title('Run_Number - Distplot')
# Out:
# Text(0.5, 1.0, 'Run_Number - Distplot')

# %%
df["Rerun_Number"].value_counts()
# Out:
# 301    10000
# Name: Rerun_Number, dtype: int64

# %% [markdown]
# The rerun number column doesn't contain any useful info, so let's drop it

# %%
df.drop("Rerun_Number",axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   J2000 Right Ascension    10000 non-null  float64
#  1   J2000 Declination        10000 non-null  float64
#  2   u                        10000 non-null  float64
#  3   g                        10000 non-null  float64
#  4   r                        10000 non-null  float64
#  5   i                        10000 non-null  float64
#  6   z                        10000 non-null  float64
#  7   Run_Number               10000 non-null  int64
#  8   Camera_column            10000 non-null  int64
#  9   Field_number             10000 non-null  int64
#  10  Space_Object_Identifier  10000 non-null  float64
#  11  object_class             10000 non-null  object
#  12  Final_Redshift           10000 non-null  float64
#  13  plate_number             10000 non-null  int64
# ...

# %%
sns.countplot(df["Camera_column"])
plt.xlabel('Camera_column')
plt.ylabel('Count')
plt.title('Camera_column - Barplot')
df["Camera_column"].value_counts()
# Out:
# 4    1834
# 5    1827
# 6    1769
# 2    1712
# 3    1560
# 1    1298
# Name: Camera_column, dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.distplot(df["Field_number"])
#plt.xticks(rotation = 90)
plt.xlabel('Field_number')
plt.ylabel('Frequency Density')
plt.title('Field_number - Distplot')
# Out:
# Text(0.5, 1.0, 'Field_number - Distplot')

# %%
df["Space_Object_Identifier"].nunique()
# Out:
# 6349

# %% [markdown]
# The dataset contains features of 6349 unique space objects

# %%
sns.countplot(df["object_class"])
plt.xlabel('object_class')
plt.ylabel('Count')
plt.title('object_class - Barplot')
df["object_class"].value_counts()
# Out:
# GALAXY    4998
# STAR      4152
# QSO        850
# Name: object_class, dtype: int64

# %% [markdown]
# Very few cases in the dataset belong to Quasars and most cases belong to Galaxies

# %%
plt.figure(figsize=(10,6))
sns.distplot(df["Final_Redshift"])
#plt.xticks(rotation = 90)
plt.xlabel('Final_Redshift')
plt.ylabel('Frequency Density')
plt.title('Final_Redshift - Distplot')
# Out:
# Text(0.5, 1.0, 'Final_Redshift - Distplot')

# %%
plt.figure(figsize=(14,8))
sns.distplot(df["plate_number"])
#plt.xticks(rotation = 90)
plt.xlabel('plate_number')
plt.ylabel('Frequency Density')
plt.title('plate_number - Distplot')
# Out:
# Text(0.5, 1.0, 'plate_number - Distplot')

# %%
plt.figure(figsize=(14,8))
sns.distplot(df["MJD_of_observation"])
#plt.xticks(rotation = 90)
plt.xlabel('MJD_of_observation')
plt.ylabel('Frequency Density')
plt.title('MJD_of_observation - Distplot')
# Out:
# Text(0.5, 1.0, 'MJD_of_observation - Distplot')

# %%
plt.figure(figsize=(14,8))
sns.distplot(df["fiber_ID"])
#plt.xticks(rotation = 90)
plt.xlabel('fiber_ID')
plt.ylabel('Frequency Density')
plt.title('fiber_ID - Distplot')
# Out:
# Text(0.5, 1.0, 'fiber_ID - Distplot')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   J2000 Right Ascension    10000 non-null  float64
#  1   J2000 Declination        10000 non-null  float64
#  2   u                        10000 non-null  float64
#  3   g                        10000 non-null  float64
#  4   r                        10000 non-null  float64
#  5   i                        10000 non-null  float64
#  6   z                        10000 non-null  float64
#  7   Run_Number               10000 non-null  int64
#  8   Camera_column            10000 non-null  int64
#  9   Field_number             10000 non-null  int64
#  10  Space_Object_Identifier  10000 non-null  float64
#  11  object_class             10000 non-null  object
#  12  Final_Redshift           10000 non-null  float64
#  13  plate_number             10000 non-null  int64
# ...

# %% [markdown]
# Biavriate analysis

# %%
plt.figure(figsize=(10,9))
sns.boxplot(x="object_class", y="fiber_ID",data=df)
plt.title('object_class vs fiber_ID')
# Out:
# Text(0.5, 1.0, 'object_class vs fiber_ID')

# %% [markdown]
# Quasers have a relatively higher values for fiber ID also galaxies have some very high outlier values for fiber ID

# %%
plt.figure(figsize=(10,9))
sns.boxplot(x="object_class", y="MJD_of_observation",data=df)
plt.title('object_class vs MJD_of_observation')
# Out:
# Text(0.5, 1.0, 'object_class vs MJD_of_observation')

# %% [markdown]
# The MJD is relatively higher for stars

# %%
plt.figure(figsize=(10,9))
sns.boxplot(x="object_class", y="plate_number",data=df)
plt.title('object_class vs plate_number')
# Out:
# Text(0.5, 1.0, 'object_class vs plate_number')

# %% [markdown]
# The plate number is relatively higher for stars

# %%
plt.figure(figsize=(10,9))
sns.boxplot(x="object_class", y="Final_Redshift",data=df)
plt.title('object_class vs Final_Redshift')
# Out:
# Text(0.5, 1.0, 'object_class vs Final_Redshift')

# %% [markdown]
# The final redshift is highest for quasars and least for stars

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   J2000 Right Ascension    10000 non-null  float64
#  1   J2000 Declination        10000 non-null  float64
#  2   u                        10000 non-null  float64
#  3   g                        10000 non-null  float64
#  4   r                        10000 non-null  float64
#  5   i                        10000 non-null  float64
#  6   z                        10000 non-null  float64
#  7   Run_Number               10000 non-null  int64
#  8   Camera_column            10000 non-null  int64
#  9   Field_number             10000 non-null  int64
#  10  Space_Object_Identifier  10000 non-null  float64
#  11  object_class             10000 non-null  object
#  12  Final_Redshift           10000 non-null  float64
#  13  plate_number             10000 non-null  int64
# ...

# %%
plt.figure(figsize=(10,9))
sns.boxplot(x="object_class", y="Field_number",data=df)
plt.title('object_class vs Field_number')
# Out:
# Text(0.5, 1.0, 'object_class vs Field_number')

# %% [markdown]
# The median field number is slightly higher for stars along with some high outlier values

# %%
plt.figure(figsize=(16,8))
sns.countplot(x="Camera_column",hue="object_class", data = df)
plt.ylabel('Count')
plt.title('object_class as per Camera_column - Barplot')
# Out:
# Text(0.5, 1.0, 'object_class as per Camera_column - Barplot')

# %% [markdown]
# Column number 5 corresponds to highest numbers of galaxies and quasars, column number 4 corresponds to highest number of stars

# %%
plt.figure(figsize=(10,9))
sns.boxplot(x="object_class", y="Run_Number",data=df)
plt.title('object_class vs Run_Number')
# Out:
# Text(0.5, 1.0, 'object_class vs Run_Number')

# %% [markdown]
# Run number is relatively higher for quasars when compared to stars or galaxies

# %%
plt.figure(figsize=(10,9))
sns.boxplot(x="object_class", y="z",data=df)
plt.title('object_class vs Response of the z band of the telescope')
# Out:
# Text(0.5, 1.0, 'object_class vs Response of the z band of the telescope')

# %% [markdown]
# Quasars have the highest response value for the z band and galaxies have the least values

# %%
plt.figure(figsize=(10,9))
sns.boxplot(x="object_class", y="i",data=df)
plt.title('object_class vs Response of the i band of the telescope')
# Out:
# Text(0.5, 1.0, 'object_class vs Response of the i band of the telescope')

# %% [markdown]
# Quasars have the highest response value for the i band and galaxies have the least values

# %%
plt.figure(figsize=(10,9))
sns.boxplot(x="object_class", y="r",data=df)
plt.title('object_class vs Response of the r band of the telescope')
# Out:
# Text(0.5, 1.0, 'object_class vs Response of the r band of the telescope')

# %% [markdown]
# Quasars have the highest response value for the r band while galaxies and stars have almost the same median values, galaxies have a lot of low value outliers

# %%
plt.figure(figsize=(10,9))
sns.boxplot(x="object_class", y="g",data=df)
plt.title('object_class vs Response of the g band of the telescope')
# Out:
# Text(0.5, 1.0, 'object_class vs Response of the g band of the telescope')

# %% [markdown]
# Quasars have the highest response value for the g band and stars have the least values

# %%
plt.figure(figsize=(10,9))
sns.boxplot(x="object_class", y="u",data=df)
plt.title('object_class vs Response of the u band of the telescope')
# Out:
# Text(0.5, 1.0, 'object_class vs Response of the u band of the telescope')

# %% [markdown]
# Quasars have the highest response value for the u band and stars have the least values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   J2000 Right Ascension    10000 non-null  float64
#  1   J2000 Declination        10000 non-null  float64
#  2   u                        10000 non-null  float64
#  3   g                        10000 non-null  float64
#  4   r                        10000 non-null  float64
#  5   i                        10000 non-null  float64
#  6   z                        10000 non-null  float64
#  7   Run_Number               10000 non-null  int64
#  8   Camera_column            10000 non-null  int64
#  9   Field_number             10000 non-null  int64
#  10  Space_Object_Identifier  10000 non-null  float64
#  11  object_class             10000 non-null  object
#  12  Final_Redshift           10000 non-null  float64
#  13  plate_number             10000 non-null  int64
# ...

# %%
plt.figure(figsize=(10,9))
sns.boxplot(x="object_class", y="J2000 Declination",data=df)
plt.title('object_class vs J2000 Declination')
# Out:
# Text(0.5, 1.0, 'object_class vs J2000 Declination')

# %% [markdown]
# Stars have a lot of high value outliers for J2000 declination

# %%
plt.figure(figsize=(10,9))
sns.boxplot(x="object_class", y="J2000 Right Ascension",data=df)
plt.title('object_class vs J2000 Right Ascension')
# Out:
# Text(0.5, 1.0, 'object_class vs J2000 Right Ascension')

# %% [markdown]
# Only stars have a high value outliers for J2000 right acsension

# %%
cor = df[["J2000 Right Ascension","J2000 Declination","u","g","r","i","z","Run_Number","Field_number","Final_Redshift","plate_number","fiber_ID"]].corr()
cor
# Out:
#                        J2000 Right Ascension  J2000 Declination         u  \
# J2000 Right Ascension               1.000000           0.003596  0.031238
# J2000 Declination                   0.003596           1.000000  0.035279
# u                                   0.031238           0.035279  1.000000
# g                                   0.043909           0.061875  0.849232
# r                                   0.047103           0.063404  0.692379
# i                                   0.045731           0.058292  0.602630
# z                                   0.042950           0.056870  0.551483
# Run_Number                         -0.092741           0.778385  0.038229
# Field_number                        0.594700          -0.131471  0.008548
# Final_Redshift                      0.030307           0.067021  0.163741
# plate_number                       -0.095329           0.088342 -0.129430
# fiber_ID                            0.057485           0.155012  0.011301
#
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(cor,cmap='Spectral',annot=True)

# %% [markdown]
# J2000 declination is strongly correlated with run number, also J2000 right ascension is moderarely correlated with field number.
# Response of the telescope bands (u, g, r, i, z) are correlated

# %%
#Let's look at the null values present in the dataset
df.isnull().sum()
# Out:
# J2000 Right Ascension      0
# J2000 Declination          0
# u                          0
# g                          0
# r                          0
# i                          0
# z                          0
# Run_Number                 0
# Camera_column              0
# Field_number               0
# Space_Object_Identifier    0
# object_class               0
# Final_Redshift             0
# plate_number               0
# MJD_of_observation         0
# fiber_ID                   0
# dtype: int64

# %% [markdown]
# There are no null values in the dataset

# %%
df.skew()
# Out:
# J2000 Right Ascension     -1.227350
# J2000 Declination          1.191544
# u                         -1.219795
# g                         -0.536293
# r                         -0.021673
# i                          0.286442
# z                          0.214313
# Run_Number                 0.412555
# Camera_column             -0.100220
# Field_number               0.249795
# Space_Object_Identifier    1.794627
# Final_Redshift             4.265729
# plate_number               1.794609
# MJD_of_observation         1.039610
# fiber_ID                   0.308053
# dtype: float64

# %%
df.head()
# Out:
#    J2000 Right Ascension  J2000 Declination         u         g         r  \
# 0             183.531326           0.089693  19.47406  17.04240  15.94699
# 1             183.598371           0.135285  18.66280  17.21449  16.67637
# 2             183.680207           0.126185  19.38298  18.19169  17.47428
# 3             183.870529           0.049911  17.76536  16.60272  16.16116
# 4             183.883288           0.102557  17.55025  16.26342  16.43869
#
#           i         z  Run_Number  Camera_column  Field_number  \
# 0  15.50342  15.22531         752              4           267
# 1  16.48922  16.39150         752              4           267
# 2  17.08732  16.80125         752              4           268
# 3  15.98233  15.90438         752              4           269
# 4  16.55492  16.61326         752              4           269
#
#    Space_Object_Identifier object_class  Final_Redshift  plate_number  \
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df["object_class"] = le.fit_transform(df["object_class"].astype('str'))
df.head()
# Out:
#    J2000 Right Ascension  J2000 Declination         u         g         r  \
# 0             183.531326           0.089693  19.47406  17.04240  15.94699
# 1             183.598371           0.135285  18.66280  17.21449  16.67637
# 2             183.680207           0.126185  19.38298  18.19169  17.47428
# 3             183.870529           0.049911  17.76536  16.60272  16.16116
# 4             183.883288           0.102557  17.55025  16.26342  16.43869
#
#           i         z  Run_Number  Camera_column  Field_number  \
# 0  15.50342  15.22531         752              4           267
# 1  16.48922  16.39150         752              4           267
# 2  17.08732  16.80125         752              4           268
# 3  15.98233  15.90438         752              4           269
# 4  16.55492  16.61326         752              4           269
#
#    Space_Object_Identifier  object_class  Final_Redshift  plate_number  \
# ...

# %%
X=df.drop("object_class", axis=1)
y=df["object_class"]

# %%
#Scaling
from sklearn.preprocessing import StandardScaler
X2 = StandardScaler().fit_transform(X)
X2
# Out:
# array([[ 0.16745842, -0.58492272,  1.03148637, ...,  1.03148936,
#          1.30931064,  0.66863177],
#        [ 0.16886159, -0.58311429,  0.05243046, ..., -0.63621258,
#         -0.87919741,  0.91101156],
#        [ 0.17057433, -0.58347525,  0.92156796, ..., -0.65633905,
#         -0.60919097,  0.77527888],
#        ...,
#        [-0.92039468,  1.46090664,  0.16753826, ...,  3.26608697,
#          2.69309363,  1.3036668 ],
#        [-0.92197294,  1.46432109,  0.31801835, ..., -0.56688806,
#         -0.70581092, -0.60143828],
#        [-0.91804124,  1.46639319,  0.79229193, ..., -0.56688806,
#         -0.70581092, -0.5820479 ]])

# %% [markdown]
# Let's do Principal Component Analysis (PCA) for the input features

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(X2)
X_pca = pca.transform(X2)
print("Original shape: {}".format(str(X2.shape)))
print("Reduced shape: {}".format(str(X_pca.shape)))
# Out:
# Original shape: (10000, 15)
# Reduced shape: (10000, 2)

# %% [markdown]
# Finding the best random state

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix,roc_curve,auc
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
max_accuracy_score=0
for r_state in range(0,100):
    X_train,X_test,y_train,y_test = train_test_split(X2,y, test_size=0.25,random_state=r_state)
    logr = LogisticRegression()
    logr.fit(X_train,y_train)
    y_pred = logr.predict(X_test)
    accu_scr = accuracy_score(y_test,y_pred)
    if accu_scr>max_accuracy_score:
        max_accuracy_score = accu_scr
        final_r_state = r_state
    
print("max accuracy score corresponding to random state",final_r_state,"is",max_accuracy_score)
# Out:
# max accuracy score corresponding to random state 57 is 0.9816

# %%
X_train,X_test,y_train,y_test = train_test_split(X2,y, test_size=0.25,random_state=57)

# %%
print(X_train.shape,"\n",X_test.shape)
# Out:
# (7500, 15)
#  (2500, 15)

# %% [markdown]
# Observing performance of different classifier algorithms

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB,MultinomialNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
import xgboost as xgb

# %%
LR = LogisticRegression()
KNN = KNeighborsClassifier()#(n_neighbors=2)
GNB = GaussianNB()
#MNB = MultinomialNB()
SV = SVC()
DTC = DecisionTreeClassifier()
RFC = RandomForestClassifier()
ABC = AdaBoostClassifier()#(n_estimators=100,base_estimator=SV,algorithm='SAMME')
GBC = GradientBoostingClassifier()
XGB = xgb.XGBClassifier(n_estimators=81,learning_rate=0.5)# from the GridSearchCV performed later

# %%
models = []
models.append(("LogisticRegression", LR))
models.append(("KNeighborsClassifier", KNN))
models.append(("GaussianNB", GNB))
#models.append(("MultinomialNB", MNB))
models.append(("SVC", SV))
models.append(("DecisionTreeClassifier", DTC))
models.append(("RandomForestClassifier", RFC))
models.append(("AdaBoostClassifier", ABC))
models.append(("GradientBoostingClassifier", GBC))
models.append(("XGBoostClassifier", XGB))

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
kf = KFold(n_splits=4, random_state=57, shuffle=True)

# %%
Model = []
score = []
cvs = []
#rocscore = []
for name,model in models:
    print("*****************",name,"******************\n")
    Model.append(name)
    model.fit(X_train,y_train)
    print(model)
    pre = model.predict(X_test)
    print("\n")
    AS = accuracy_score(y_test,pre)
    print("Accuracy Score = ",AS)
    score.append(AS*100)
    print("\n")
    sc = cross_val_score(model,X,y,cv=kf,scoring="accuracy").mean()
    print("Cross val score = ",sc)
    cvs.append(sc*100)
    print("\n")
    #false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test,pre)
    #roc_auc = auc( false_positive_rate, true_positive_rate)
    #print("roc_auc_score = ",roc_auc)
    #rocscore.append(roc_auc*100)
    #print("\n")
    print("Classification Report\n", classification_report(y_test,pre))
    print("\n")
    cm = confusion_matrix(y_test,pre)
    print("Confusion Matrix \n{}".format(cm))
    print("\n")
    plt.figure(figsize = (10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    #plt.subplot(912)
    #plt.title(name)
    #plt.plot(false_positive_rate, true_positive_rate,label = "AUC = %0.2f"% roc_auc)
    #plt.plot([0,1],[0,1],'r--')
    #plt.legend(loc = 'lower right')
    #plt.ylabel("True positive rate")
    #plt.xlabel("False positive rate")
    print("\n\n")
# Out:
# ***************** LogisticRegression ******************
#
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
#
#
# Accuracy Score =  0.9816
#
#
# Cross val score =  0.4998
#
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1271
#            1       1.00      0.94      0.97       222
#            2       0.97      0.99      0.98      1007
#
#     accuracy                           0.98      2500
#    macro avg       0.98      0.97      0.98      2500
# weighted avg       0.98      0.98      0.98      2500
#
#
#
# Confusion Matrix
# [[1244    1   26]
#  [  13  209    0]
#  [   6    0 1001]]
#
#
# ...

# %%
result = pd.DataFrame({"Model": Model, "Accuracy Socre": score, "Cross val score": cvs})
result
# Out:
#                         Model  Accuracy Socre  Cross val score
# 0          LogisticRegression           98.16            49.98
# 1        KNeighborsClassifier           91.68            78.46
# 2                  GaussianNB           95.32            79.65
# 3                         SVC           96.20            79.68
# 4      DecisionTreeClassifier           98.84            98.49
# 5      RandomForestClassifier           99.16            98.85
# 6          AdaBoostClassifier           91.88            89.54
# 7  GradientBoostingClassifier           98.84            98.83
# 8           XGBoostClassifier           99.28            99.00

# %% [markdown]
# Parameter tuning for the best performing model

# %%
from sklearn.model_selection import GridSearchCV
parameters = {
              'n_estimators': [81,100],
                'learning_rate': [0.5,0.6,0.8]
             }
grid = GridSearchCV(estimator=XGB,param_grid=parameters)
grid.fit(X_train,y_train)
print(grid)
print(grid.best_score_)
print(grid.best_estimator_.learning_rate)
print(grid.best_params_)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      colsample_bylevel=1, colsample_bynode=1,
#                                      colsample_bytree=1, gamma=0, gpu_id=-1,
#                                      importance_type='gain',
#                                      interaction_constraints='',
#                                      learning_rate=0.300000012,
#                                      max_delta_step=0, max_depth=6,
#                                      min_child_weight=1, missing=nan,
#                                      monotone_constraints='()', n_estimators=81,
#                                      n_j...llel_tree=1,
#                                      objective='multi:softprob', random_state=0,
#                                      reg_alpha=0, reg_lambda=1,
#                                      scale_pos_weight=None, subsample=1,
# ...

# %% [markdown]
# XGBoost classifier gives the highest accuracy and generalization, so let's save this model

# %%
from sklearn.externals import joblib
joblib.dump(XGB,'Space_Object_Class.pkl')
# Out:
# ['Space_Object_Class.pkl']
